# %% [markdown]
# # Fishcounter Training Setup

# %%
# Mount Project's Google Drive
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/FISHCOUNTER_TRAINING/
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/FISHCOUNTER_TRAINING
# annotations  configs  models  patin-dataset  scripts  YOLOv6

# %%
# Clone the repository
# !git clone https://github.com/airockchip/YOLOv6.git
# Out:
# fatal: destination path 'YOLOv6' already exists and is not an empty directory.

# %%
# Install requirements
# !pip install -r ./YOLOv6/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 103.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 85.0 MB/s eta 0:00:00
# ...

# %%
# Uninstall the torch
# !pip uninstall -y torch torchvision torchaudio
# Install the torch version 2.5.1
# !pip install torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 90.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 94.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 5.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
# ...

# %% [markdown]
# # Fishcounter Training Model

# %%
# %cd /content/drive/MyDrive/FISHCOUNTER_TRAINING/
# !ls
# Out:
# /content/drive/MyDrive/FISHCOUNTER_TRAINING
# annotations  configs  models  patin-dataset  scripts  YOLOv6

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# %cd /content/drive/MyDrive/FISHCOUNTER_TRAINING/YOLOv6/
# !python ./tools/train.py \
  --img 640 \
  --batch 8 \
  --epochs 1 \
  --data ../patin-dataset/data.yaml \
  --conf ../configs/yolov6n_config.py \
  --fuse_ab \
  --device 0
# Out:
# /content/drive/MyDrive/FISHCOUNTER_TRAINING/YOLOv6
# 2025-07-31 07:23:12.926982: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753946593.232465    1530 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753946593.312300    1530 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-31 07:23:13.928702: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %% [markdown]
# # Utilites

# %%
# %cd /content/drive/MyDrive/FISHCOUNTER_TRAINING/scripts
# !python ./modify_instances_valid.py

# %% [markdown]
# #FOR LOCAL

# %%
cd FISHCOUNTER_TRAINING/
# Out:
# c:\ITB\KP\kp\github\fishcounter\training\FISHCOUNTER_TRAINING
# C:\Users\Arvin Nathaniel\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is EA6C-89E0
#
#  Directory of c:\ITB\KP\kp\github\fishcounter\training\FISHCOUNTER_TRAINING
#
# 04/08/2025  07:36    <DIR>          .
# 01/08/2025  07:49    <DIR>          ..
# 01/01/1980  00:00    <DIR>          .ipynb_checkpoints
# 31/07/2025  14:31    <DIR>          annotations
# 31/07/2025  14:31    <DIR>          configs
# 04/08/2025  07:53    <DIR>          models
# 31/07/2025  15:24    <DIR>          patin-dataset
# 04/08/2025  07:36    <DIR>          rknn_model_zoo
# 31/07/2025  14:31    <DIR>          scripts
# 04/08/2025  07:17    <DIR>          YOLOv6
#                0 File(s)              0 bytes
#               10 Dir(s)  103.694.622.720 bytes free

# %%
# Clone the repository
# !git clone https://github.com/airockchip/YOLOv6.git
# Out:
# Cloning into 'YOLOv6'...

# %%
cd YOLOv6/
# Out:
# c:\ITB\KP\kp\github\fishcounter\training\FISHCOUNTER_TRAINING\YOLOv6

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is EA6C-89E0
#
#  Directory of c:\ITB\KP\kp\github\fishcounter\training\FISHCOUNTER_TRAINING\YOLOv6
#
# 04/08/2025  07:17    <DIR>          .
# 04/08/2025  07:36    <DIR>          ..
# 01/08/2025  11:34    <DIR>          .github
# 01/08/2025  11:34             1.397 .gitignore
# 01/08/2025  11:34               183 .pre-commit-config.yaml
# 01/08/2025  11:34    <DIR>          assets
# 04/08/2025  07:17        18.561.656 best_ckpt.onnx
# 02/08/2025  08:38        10.456.314 best_ckpt.pt
# 01/08/2025  11:34    <DIR>          configs
# 01/08/2025  11:34    <DIR>          data
# 01/08/2025  11:34    <DIR>          deploy
# 01/08/2025  11:34    <DIR>          docs
# 01/08/2025  11:34             7.455 hubconf.py
# 01/08/2025  11:34         4.954.841 inference.ipynb
# 01/08/2025  11:34            35.823 LICENSE
# 01/08/2025  11:34            16.398 README.md
# 01/08/2025  11:34            15.733 README_cn.md
# ...

# %%
pip install -e .
# Out:
# Obtaining file:///C:/ITB/KP/kp/github/fishcounter/training/FISHCOUNTER_TRAINING/YOLOv6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: file:///C:/ITB/KP/kp/github/fishcounter/training/FISHCOUNTER_TRAINING/YOLOv6 does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %% [markdown]
# Training is as below :

# %%
# Train the model with the modified dataset
# Ultra-conservative training for RKNN compatibility
# !python -m tools.train \
  --img 640 \
  --batch 16 \
  --epochs 1 \
  --data ../patin-dataset/data.yaml \
  --conf ./configs/yolov6n_finetune.py \
  --device 0 \
  --workers 0
# Out:
# Using 1 GPU for training...
# training args are: Namespace(data_path='../patin-dataset/data.yaml', conf_file='./configs/yolov6n_finetune.py', img_size=640, batch_size=16, epochs=1, workers=0, device='0', eval_interval=20, eval_final_only=False, heavy_eval_range=50, check_images=False, check_labels=False, output_dir='./runs/train', name='exp', dist_url='env://', gpu_count=0, local_rank=-1, resume=False, write_trainbatch_tb=False, stop_aug_last_n_epoch=15, save_ckpt_on_last_n_epoch=-1, distill=False, distill_feat=False, quant=False, calib=False, teacher_model_path=None, temperature=20, fuse_ab=False, bs_per_gpu=32, rank=-1, world_size=1, save_dir='runs\\train\\exp10')
#
# Train: Final numbers of valid images: 849/ labels: 849.
# 0.1s for dataset initialization.
# Convert to COCO format
#
# ...
# 100%|██████████| 79/79 [00:00<00:00, 31321.49it/s]
# ...
